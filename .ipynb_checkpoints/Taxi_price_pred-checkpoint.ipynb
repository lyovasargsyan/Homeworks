# %%
import numpy as np
import pandas as pd
import matplotlib as plt 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('taxi_trip_pricing.csv')

# %%
data
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  ...  Per_Minute_Rate Trip_Duration_Minutes Trip_Price
# 0               19.35     Morning     Weekday  ...             0.32                 53.82    36.2624
# 1               47.59   Afternoon     Weekday  ...             0.43                 40.57        NaN
# 2               36.87     Evening     Weekend  ...             0.15                 37.27    52.9032
# 3               30.33     Evening     Weekday  ...             0.15                116.81    36.4698
# 4                 NaN     Evening     Weekday  ...             0.32                 22.64    15.6180
# ..                ...         ...         ...  ...              ...                   ...        ...
# 995              5.49   Afternoon     Weekend  ...             0.49                 58.39    34.4049
# 996             45.95       Night     Weekday  ...              NaN                 61.96    62.1295
# 997              7.70     Morning     Weekday  ...              NaN                 54.18    33.1236
# 998             47.56     Morning     Weekday  ...             0.17                114.94    61.2090
# 999             22.85     Morning     Weekend  ...             0.23                 29.69    45.4437
#
# [1000 rows x 11 columns]

# %%
data["Per_Km_Rate"] = data["Per_Km_Rate"].fillna(data["Per_Km_Rate"].mean())

# %%
data.Day_of_Week.fillna("Weekday")
data.Day_of_Week = (data["Day_of_Week"] == "Weekday").astype("int8")

# %%
data["Time_of_Day"] = data["Time_of_Day"].fillna(data["Time_of_Day"].mode()[0])
data = pd.get_dummies(data, columns=["Time_of_Day"], dtype = "int8")

# %%
data.Trip_Distance_km = data.Trip_Distance_km.fillna(data.Trip_Distance_km.mean())

# %%
data["Traffic_Conditions"] = data["Traffic_Conditions"].fillna(data["Traffic_Conditions"].mode()[0])
data = pd.get_dummies(data, columns=["Traffic_Conditions"], dtype = "int8")

# %%
data["Weather"] = data["Weather"].fillna(data["Weather"].mode()[0])
data = pd.get_dummies(data, columns=["Weather"], dtype = "int8")

# %%
data["Base_Fare"] = data["Base_Fare"].fillna(data["Base_Fare"].mode()[0])

# %%
data["Per_Minute_Rate"] = data["Per_Minute_Rate"].fillna(data["Per_Minute_Rate"].mean())

# %%
data["Trip_Duration_Minutes"] = data["Trip_Duration_Minutes"].fillna(data["Trip_Duration_Minutes"].mean())

# %%
data["Trip_Price"] = data["Trip_Price"].fillna(data["Trip_Price"].mean())

# %%
data["Passenger_Count"] = data["Passenger_Count"].fillna(data["Passenger_Count"].mean().round()).astype('int8')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Trip_Distance_km           1000 non-null   float64
#  1   Day_of_Week                1000 non-null   int8
#  2   Passenger_Count            1000 non-null   int8
#  3   Base_Fare                  1000 non-null   float64
#  4   Per_Km_Rate                1000 non-null   float64
#  5   Per_Minute_Rate            1000 non-null   float64
#  6   Trip_Duration_Minutes      1000 non-null   float64
#  7   Trip_Price                 1000 non-null   float64
#  8   Time_of_Day_Afternoon      1000 non-null   int8
#  9   Time_of_Day_Evening        1000 non-null   int8
#  10  Time_of_Day_Morning        1000 non-null   int8
#  11  Time_of_Day_Night          1000 non-null   int8
#  12  Traffic_Conditions_High    1000 non-null   int8
#  13  Traffic_Conditions_Low     1000 non-null   int8
#  14  Traffic_Conditions_Medium  1000 non-null   int8
#  15  Weather_Clear              1000 non-null   int8
#  16  Weather_Rain               1000 non-null   int8
#  17  Weather_Snow               1000 non-null   int8
# dtypes: float64(6), int8(12)
# memory usage: 58.7 KB

# %%
y = data.Trip_Price.values
x = data.drop("Trip_Price", axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(x_train)
X_test_poly = poly.fit_transform(x_test)

# %%
model = LinearRegression()
model.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_poly)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mse, r2
# Out:
# (89.06708316478665, 0.892737306913132)
